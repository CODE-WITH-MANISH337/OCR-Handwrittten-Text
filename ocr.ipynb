# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import easyocr

# %%
image_path='images/images.jpeg'

reader=easyocr.Reader(['en'])
result=reader.readtext(image_path)
print(result)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\Users\Dell\Desktop\OCR-Handwrittten-Text\venv\Lib\site-packages\torch\utils\data\dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# [([[np.int32(18), np.int32(18)], [np.int32(293), np.int32(18)], [np.int32(293), np.int32(145)], [np.int32(18), np.int32(145)]], 'SURF', np.float64(0.9862082004547119))]

# %%
result[0][1]
# Out:
# 'SURF'
